# %% [markdown]
# <a href="https://colab.research.google.com/github/overclock98/FOTS_OCR_evaluate_coco_2014/blob/master/FOTS_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/Masao-Taketani/FOTS_OCR

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import os

if "FOTS_OCR" not in os.getcwd():
    # !git clone https://github.com/Masao-Taketani/FOTS_OCR.git

os.chdir('FOTS_OCR/')
# !wget https://github.com/Pay20Y/FOTS_TF/releases/download/v2/SynthText_6_epochs.tar -P ckpt/
# !tar -xvf ckpt/SynthText_6_epochs.tar -C /content/FOTS_OCR/ckpt
# Out:
# Cloning into 'FOTS_OCR'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 487 (delta 29), reused 29 (delta 13), pack-reused 432
# Receiving objects: 100% (487/487), 1015.62 KiB | 3.48 MiB/s, done.
# Resolving deltas: 100% (260/260), done.
# --2020-07-02 15:01:55--  https://github.com/Pay20Y/FOTS_TF/releases/download/v2/SynthText_6_epochs.tar
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://www.veeqo.com/wp-content/themes/ss88/images/integrations/dhlparcel/dhlparcel-header.png -P /content/FOTS_OCR/test_imgs
# Out:
# --2020-07-02 15:02:13--  https://www.veeqo.com/wp-content/themes/ss88/images/integrations/dhlparcel/dhlparcel-header.png
# Resolving www.veeqo.com (www.veeqo.com)... 3.11.26.182
# Connecting to www.veeqo.com (www.veeqo.com)|3.11.26.182|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162026 (158K) [image/png]
# Saving to: ‘/content/FOTS_OCR/test_imgs/dhlparcel-header.png’
#
# dhlparcel-header.pn 100%[===================>] 158.23K   611KB/s    in 0.3s
#
# 2020-07-02 15:02:14 (611 KB/s) - ‘/content/FOTS_OCR/test_imgs/dhlparcel-header.png’ saved [162026/162026]

# %%
# !wget https://d39w7f4ix9f5s9.cloudfront.net/dims4/default/4826f49/2147483647/strip/true/crop/2999x3503+0+0/resize/1283x1499!/quality/90/?url=http%3A%2F%2Famazon-blogs-brightspot.s3.amazonaws.com%2F1f%2F41%2F144becc548418c82c6def60dbf9d%2F20190214amznshippinglabel-js-01-labeled-r2.jpg -O /content/FOTS_OCR/test_imgs/labeled-r2.jpg
# Out:
# --2020-07-02 15:02:23--  https://d39w7f4ix9f5s9.cloudfront.net/dims4/default/4826f49/2147483647/strip/true/crop/2999x3503+0+0/resize/1283x1499!/quality/90/?url=http%3A%2F%2Famazon-blogs-brightspot.s3.amazonaws.com%2F1f%2F41%2F144becc548418c82c6def60dbf9d%2F20190214amznshippinglabel-js-01-labeled-r2.jpg
# Resolving d39w7f4ix9f5s9.cloudfront.net (d39w7f4ix9f5s9.cloudfront.net)... 13.224.29.173, 13.224.29.91, 13.224.29.110, ...
# Connecting to d39w7f4ix9f5s9.cloudfront.net (d39w7f4ix9f5s9.cloudfront.net)|13.224.29.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229191 (224K) [image/jpeg]
# Saving to: ‘/content/FOTS_OCR/test_imgs/labeled-r2.jpg’
#
# /content/FOTS_OCR/t 100%[===================>] 223.82K   791KB/s    in 0.3s
#
# 2020-07-02 15:02:24 (791 KB/s) - ‘/content/FOTS_OCR/test_imgs/labeled-r2.jpg’ saved [229191/229191]

# %%
from google.colab.patches import cv2_imshow

# %%
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
import cv2
img = cv2.imread('/content/FOTS_OCR/test_imgs/dhlparcel-header.png', cv2.IMREAD_UNCHANGED)
#cv2_imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
#!cp -r /content/drive/"My Drive/Colab Notebooks"/FOTS/synthText_10eps /content/FOTS_OCR

# %%
# !python test.py --test_data_path test_imgs/ --checkpoint_path /content/FOTS_OCR/ckpt/SynthText_6_epochs
# Out:
# make: Entering directory '/content/FOTS_OCR/lanms'
# g++ -o adaptor.so -I include  -std=c++11 -O3 -I/usr/include/python3.6m -I/usr/include/python3.6m  -Wno-unused-result -Wsign-compare -g -fdebug-prefix-map=/build/python3.6-PHwBoS/python3.6-3.6.9=. -specs=/usr/share/dpkg/no-pie-compile.specs -fstack-protector -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O3 -Wall -L/usr/lib/python3.6/config-3.6m-x86_64-linux-gnu -L/usr/lib -lpython3.6m -lpthread -ldl  -lutil -lm  -Xlinker -export-dynamic -Wl,-O1 -Wl,-Bsymbolic-functions adaptor.cpp include/clipper/clipper.cpp --shared -fPIC
# In file included from include/pybind11/pytypes.h:12:0,
#                  from include/pybind11/cast.h:13,
#                  from include/pybind11/attr.h:13,
#                  from include/pybind11/pybind11.h:43,
#                  from adaptor.cpp:1:
# adaptor.cpp: In function ‘PyObject* PyInit_adaptor()’:
# ...

# %%
img = cv2.imread('/content/FOTS_OCR/outputs/dhlparcel-header.png', cv2.IMREAD_UNCHANGED)
#cv2_imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
# !cat /content/FOTS_OCR/outputs/res_dhlparcel-header.txt
# Out:
# 209,734,345,744,343,766,207,756,SWANSEA
# 253,257,492,247,493,269,254,279,CNED+SIGNATuI
# 1040,471,1125,499,1114,533,1030,505,Dod
# 209,765,325,773,323,798,207,789,sa/1NW
# 223,826,492,845,490,864,222,845,>ackngw3l64troe
# 216,669,336,676,335,696,215,689,ECHHuB
# 1360,961,1441,936,1451,971,1370,995,ElDd
# 211,637,296,642,295,661,210,656,IEEQO
# 782,209,962,215,961,257,781,251,DHL
# 1457,822,1524,805,1533,842,1466,860,10
# 206,929,309,925,310,939,206,943,ATD2T0740tom
# 285,212,479,221,478,243,283,234,Daydelivery
# 692,528,809,536,808,557,690,548,234:343:29
# 214,973,279,979,277,991,213,985,2204038
# 213,221,307,215,308,234,215,240,lEXTD
# 197,509,262,514,261,542,195,538,Dr
# 832,269,896,271,896,284,831,283,paRCEl
# 293,899,371,906,370,924,292,917,15MMay19
# 345,342,438,349,436,366,343,359,1492839
# 207,952,278,955,277,968,207,965,Refcode7?
# 196,907,307,902,307,919,197,924,Shipdate:15
# 825,531,902,534,901,550,824,548,192889
# 244,950,356,955,356,969,244,964,de26-1327HF-26
# ...

# %%
img = cv2.imread('/content/FOTS_OCR/outputs/labeled-r2.jpg', cv2.IMREAD_UNCHANGED)
#cv2_imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
